# %%
import numpy as np
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt

# %%
# Load the data
file_path = Path('C:/Users/OgyYi/Desktop/final projesi son/loans.csv')

loans_df = pd.read_csv(file_path)
loans_df.head(3)
# Out:
#    LOAN_ID          LOAN_NAME ORIGINAL_LANGUAGE  \
# 0  1829511              Gemma           English
# 1   671202  Brillyd Alexandra           Spanish
# 2  1068921              Niuia           English
#
#                                          DESCRIPTION  \
# 0  Gemma works hard to support six children. She ...
# 1  Brillyd Alexandra es una mujer de 21 años de e...
# 2  Niuia is a 71 year old widow with 8 children. ...
#
#                               DESCRIPTION_TRANSLATED  FUNDED_AMOUNT  \
# 0  Gemma works hard to support six children. She ...          150.0
# 1  Brillyd Alexandra, age 21, has a four year old...          375.0
# 2  Niuia is a 71 year old widow with 8 children. ...          400.0
#
#    LOAN_AMOUNT  STATUS   IMAGE_ID  VIDEO_ID  ... LENDER_TERM  \
# 0        150.0  funded  3244438.0       NaN  ...        13.0
# 1        375.0  funded  1531875.0       NaN  ...         6.0
# 2        400.0  funded  2180352.0       NaN  ...        14.0
#
# ...

# %%
# All rows
loans_df.head(5)
# Out:
#    LOAN_ID          LOAN_NAME ORIGINAL_LANGUAGE  \
# 0  1829511              Gemma           English
# 1   671202  Brillyd Alexandra           Spanish
# 2  1068921              Niuia           English
# 3   576047            Jonalyn           English
# 4   898022              Meena           English
#
#                                          DESCRIPTION  \
# 0  Gemma works hard to support six children. She ...
# 1  Brillyd Alexandra es una mujer de 21 años de e...
# 2  Niuia is a 71 year old widow with 8 children. ...
# 3  Jonalyn, age 29, raises hogs to earn an income...
# 4  Meena is 45 years old married woman, residing ...
#
#                               DESCRIPTION_TRANSLATED  FUNDED_AMOUNT  \
# 0  Gemma works hard to support six children. She ...          150.0
# 1  Brillyd Alexandra, age 21, has a four year old...          375.0
# 2  Niuia is a 71 year old widow with 8 children. ...          400.0
# 3                                                NaN          250.0
# ...

# %%
#drop null values
dropped_loans_df = loans_df.dropna(axis='columns', how='all')

# %%
# Drop non-values
dropped_loans_df.tail()
# Out:
#          LOAN_ID      LOAN_NAME ORIGINAL_LANGUAGE  \
# 1940390  1039021   Katty Milena           Spanish
# 1940391  1433886  Thaphae Group           English
# 1940392  1969699          Shehu           English
# 1940393      123       Margaret           English
# 1940394  1420011         Mathew           English
#
#                                                DESCRIPTION  \
# 1940390  Katty, es una joven de 24 años de edad que des...
# 1940391  Chan understands the difference the water filt...
# 1940392  Shehu who is 49  years of age and married with...
# 1940393  Margaret is married with nine children.\r\n<br...
# 1940394  I grew up in San Francisco in the Lakeview nei...
#
#                                     DESCRIPTION_TRANSLATED  FUNDED_AMOUNT  \
# 1940390  Katty is a 24 year old young lady.  For some t...          325.0
# 1940391  Chan understands the difference the water filt...          175.0
# 1940392  Shehu who is 49  years of age and married with...          300.0
# ...

# %%
sample_loans_df = loans_df.sample(frac =.001)

# %%
sample_loans_df.tail(5)
# Out:
#          LOAN_ID         LOAN_NAME ORIGINAL_LANGUAGE  \
# 447859   1296135             Zakia           English
# 1195874   491888  ORANGEL HIPOLITO           Spanish
# 743122   1832345             Elisa           English
# 874687   1103974             MILYN           English
# 1776530   694455           Mojahed           English
#
#                                                DESCRIPTION  \
# 447859   Zakia is 37 years old, a married lady. She is ...
# 1195874  Orangel,  Vive con su esposa y cinco hijos, la...
# 743122   Elisa is a hardworking micro-entrepreneur.  Sh...
# 874687   Milyn, aged 36, is married to a farmer. She is...
# 1776530  Mojahed is a 22-year-old single man from a sma...
#
#                                     DESCRIPTION_TRANSLATED  FUNDED_AMOUNT  \
# 447859   Zakia is 37 years old, a married lady. She is ...          300.0
# 1195874  Orangel lives with his wife and five children....          425.0
# ...

# %%
sample_loans_df.columns
# Out:
# Index(['LOAN_ID', 'LOAN_NAME', 'ORIGINAL_LANGUAGE', 'DESCRIPTION',
#        'DESCRIPTION_TRANSLATED', 'FUNDED_AMOUNT', 'LOAN_AMOUNT', 'STATUS',
#        'IMAGE_ID', 'VIDEO_ID', 'ACTIVITY_NAME', 'SECTOR_NAME', 'LOAN_USE',
#        'COUNTRY_CODE', 'COUNTRY_NAME', 'TOWN_NAME', 'CURRENCY_POLICY',
#        'CURRENCY_EXCHANGE_COVERAGE_RATE', 'CURRENCY', 'PARTNER_ID',
#        'POSTED_TIME', 'PLANNED_EXPIRATION_TIME', 'DISBURSE_TIME',
#        'RAISED_TIME', 'LENDER_TERM', 'NUM_LENDERS_TOTAL',
#        'NUM_JOURNAL_ENTRIES', 'NUM_BULK_ENTRIES', 'TAGS', 'BORROWER_NAMES',
#        'BORROWER_GENDERS', 'BORROWER_PICTURED', 'REPAYMENT_INTERVAL',
#        'DISTRIBUTION_MODEL'],
#       dtype='object')

# %%
loans_columns_picked_df = sample_loans_df[['LOAN_NAME', 'ACTIVITY_NAME', 'COUNTRY_NAME','TOWN_NAME', 'DESCRIPTION', 'LOAN_AMOUNT', ]]
loans_columns_picked_df.head(65)
# Out:
#                LOAN_NAME              ACTIVITY_NAME COUNTRY_NAME  \
# 1240830              NaN                  Tailoring   Mozambique
# 1568204           Tolkun                      Dairy   Kyrgyzstan
# 1527648          Cynthia          Natural Medicines  Philippines
# 1553743  Chameli's Group  Personal Housing Expenses        India
# 539921              JANE                  Tailoring        Kenya
# ...                  ...                        ...          ...
# 966554             Zoila                 Food Stall         Peru
# 1272665            Betty                    Farming        Kenya
# 174943              Diễm            Home Appliances      Vietnam
# 1878163             Tini  Personal Housing Expenses    Indonesia
# 1170590         Chausiku        Fruits & Vegetables        Kenya
#
#                               TOWN_NAME  \
# 1240830                             NaN
# 1568204  Kochkor district, Naryn region
# 1527648   Kabankalan, Negros Occidental
# ...

# %%
six_countries_df=loans_columns_picked_df.iloc[[4, 8, 63, 85, 161, 386], :]
six_countries_df
# Out:
#               LOAN_NAME              ACTIVITY_NAME   COUNTRY_NAME  \
# 539921             JANE                  Tailoring          Kenya
# 473233            Arati  Personal Housing Expenses          India
# 1878163            Tini  Personal Housing Expenses      Indonesia
# 263044          Jessica                     Health  United States
# 1248697  Claudia Jimena     Higher education costs        Bolivia
# 1217035            Anna              Farm Supplies        Ukraine
#
#                 TOWN_NAME                                        DESCRIPTION  \
# 539921             Nakuru  Jane is a married woman. She has two children....
# 473233   Phulbani, Odisha  Arati is a 29-year-old woman from a village in...
# 1878163             Lebak  Good day, lenders! Meet one of KSPPS BMI’s cli...
# 263044         Portsmouth  Over twenty years ago something happened that ...
# 1248697        Chuquisaca  Claudia has always dreamed of becoming a profe...
# ...

# %%
six_countries_df.to_csv(r'C:\Users\OgyYi\Desktop\final projesi son\six_countries.csv', index = False)
